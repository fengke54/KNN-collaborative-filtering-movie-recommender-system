# %%
###DSC478 Visualization WordCloud 
import pandas as pd
# %matplotlib inline
import wordcloud
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
#Import Files 
movies = pd.read_csv('titles.csv', encoding = "ISO-8859-1", header = None, names = ['Movie_Id', 'Year', 'Name'])

# %%
#WordCloud
movies['Name'] = movies['Name'].fillna("").astype('str')
titlec = ' '.join(movies['Name'])
titlew = WordCloud(stopwords=STOPWORDS, background_color='black', height=1000, width=3000).generate(title_corpus)
plt.figure(figsize=(14,7))
plt.imshow(titlew)
plt.axis('off')
plt.title('Ke Feng WordCloud')
plt.show()
